# %%
import sys
import os
import numpy as np
import pickle # Thư viện dùng để lưu Model xuống ổ cứng
import matplotlib.pyplot as plt

# Thêm đường dẫn src
sys.path.append(os.path.abspath('../src'))

# Import các class core từ src
from model import MLP
from layers import Dense
from activations import ReLU, Linear
from losses import MSE
from optimizer import SGD

# Cấu hình hiển thị
# %matplotlib inline

print("Đã import xong các thư viện và module từ src!")
# Out:
# Đã import xong các thư viện và module từ src!

# %%
# Path to the directory containing clean data
processed_dir = os.path.join('..', 'data', 'processed')

print(f"Reading data from: {os.path.abspath(processed_dir)}")

# Load data
try:
    X_train = np.load(os.path.join(processed_dir, 'X_train.npy'))
    y_train = np.load(os.path.join(processed_dir, 'y_train.npy'))
    
    # === THE FIX: Load Test Data ===
    X_test = np.load(os.path.join(processed_dir, 'X_test.npy'))
    y_test = np.load(os.path.join(processed_dir, 'y_test.npy'))
    
    print("Data loaded successfully!")
    print(f"X_train shape: {X_train.shape}")
    print(f"y_train shape: {y_train.shape}")
    print(f"X_test shape: {X_test.shape}")
    print(f"y_test shape: {y_test.shape}")
    
except FileNotFoundError:
    print("Error: Data files not found. Please run Notebook 02 first!")
# Out:
# Reading data from: /home/bush/Desktop/mlp-california-housing-price-prediction/data/processed
# Data loaded successfully!
# X_train shape: (16346, 13)
# y_train shape: (16346, 1)
# X_test shape: (4087, 13)
# y_test shape: (4087, 1)

# %%
# [CELL 3] - CẬP NHẬT CẤU TRÚC CHAMPION
n_features = X_train.shape[1]
model = MLP()

# === KIẾN TRÚC 3 LỚP (Winner Kịch bản 3) ===
model.add(Dense(n_features, 64))
model.add(ReLU())
model.add(Dense(64, 32))
model.add(ReLU())
model.add(Dense(32, 16))  # Lớp sâu giúp học tốt hơn
model.add(ReLU())
model.add(Dense(16, 1))
model.add(Linear())

# === LEARNING RATE (Winner Kịch bản 1) ===
# Dùng 0.001 cho an toàn và ổn định
learning_rate=0.001
model.compile(loss_function=MSE(), optimizer=SGD(learning_rate=0.001))

# %%
epochs = 100
batch_size = 16
losses = []
val_losses = [] # 1. Create a list to store test/validation loss

print(f"🚀 Starting training for {epochs} epochs...")

for epoch in range(epochs):
    epoch_loss = 0
    
    # === Shuffle data at the beginning of each epoch ===
    indices = np.arange(len(X_train))
    np.random.shuffle(indices)
    
    X_train_shuffled = X_train[indices]
    y_train_shuffled = y_train[indices]
    
    # === Training Phase ===
    for i in range(0, len(X_train), batch_size):
        x_batch = X_train_shuffled[i:i+batch_size]
        y_batch = y_train_shuffled[i:i+batch_size]
        
        # Train Step updates the weights and returns the batch loss
        loss = model.train_step(x_batch, y_batch)
        epoch_loss += loss
    
    # Calculate average training loss for the epoch
    avg_loss = epoch_loss / (len(X_train) / batch_size)
    losses.append(avg_loss)
    
    # === Validation/Test Phase ===
    # 2. Predict on X_test and calculate loss without updating weights
    val_predictions = model.predict(X_test)
    val_loss = model.loss_function.forward(val_predictions, y_test)
    val_losses.append(val_loss)
    
    # Print progress
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_loss:.5f} | Test Loss: {val_loss:.5f}")

print("🎉 Training completed!")
# Out:
# 🚀 Starting training for 100 epochs...
# Epoch 10/100 - Train Loss: 0.36575 | Test Loss: 0.38627
# Epoch 20/100 - Train Loss: 0.33115 | Test Loss: 0.35880
# Epoch 30/100 - Train Loss: 0.31410 | Test Loss: 0.34221
# Epoch 40/100 - Train Loss: 0.30081 | Test Loss: 0.33223
# Epoch 50/100 - Train Loss: 0.29189 | Test Loss: 0.32453
# Epoch 60/100 - Train Loss: 0.28379 | Test Loss: 0.31854
# Epoch 70/100 - Train Loss: 0.27827 | Test Loss: 0.31100
# Epoch 80/100 - Train Loss: 0.27363 | Test Loss: 0.31503
# Epoch 90/100 - Train Loss: 0.26968 | Test Loss: 0.30977
# Epoch 100/100 - Train Loss: 0.26574 | Test Loss: 0.30154
# 🎉 Training completed!

# %%
# === Plotting ===
plt.figure(figsize=(10, 6))

# Plot both lines
plt.plot(losses, label='Training Loss', color='blue', linewidth=2)
plt.plot(val_losses, label='Test/Validation Loss', color='orange', linewidth=2)

plt.title(f"Training vs Validation Loss (Learning Rate={learning_rate})", fontsize=14, fontweight='bold')
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("MSE Loss", fontsize=12)
plt.legend(fontsize=11)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# === Quick Evaluation ===
print(f"Initial Train Loss: {losses[0]:.4f}  -> Final: {losses[-1]:.4f}")
print(f"Initial Test Loss:  {val_losses[0]:.4f} -> Final: {val_losses[-1]:.4f}")

if val_losses[-1] < val_losses[0] and val_losses[-1] <= losses[-1] * 1.5:
    print("Evaluation: Model is LEARNING well, generalizing stably on the Test set.")
elif val_losses[-1] > losses[-1] * 1.5:
    print("Evaluation: WARNING - OVERFITTING! Train Loss is decreasing but Test Loss is stalling or increasing.")
else:
    print("Evaluation: Model is NOT LEARNING (Loss not decreasing). Check the architecture or Learning Rate.")
# Out:
# Initial Train Loss: 1.0882  -> Final: 0.2657
# Initial Test Loss:  0.6682 -> Final: 0.3015
# Evaluation: Model is LEARNING well, generalizing stably on the Test set.

# %%
# Tạo thư mục models nếu chưa có
models_dir = os.path.join('..', 'models')
os.makedirs(models_dir, exist_ok=True)

# Đường dẫn file model
model_path = os.path.join(models_dir, 'mlp_model.pkl')

# Lưu object model vào file
with open(model_path, 'wb') as f:
    pickle.dump(model, f)

print(f"Đã lưu model thành công tại: {os.path.abspath(model_path)}")
# Out:
# Đã lưu model thành công tại: /home/bush/Desktop/mlp-california-housing-price-prediction/models/mlp_model.pkl
